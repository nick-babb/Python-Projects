# %% [markdown]
# # 01. Importing libraries and data sets

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Creating a Path

# %%
path = r'C:\Users\chris\Desktop\Upskilling\CareerFoundry\Data Immersion\Achievement 4\08-2025 Instacart Basket Analysis'

# %% [markdown]
# Importing data sets

# %%
df_ords = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'order_products_merged.pkl'))

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order first_order  product_id  add_to_cart_order  \
# 0                     0.0         yes         196                  1
# 1                     0.0         yes       14084                  2
# 2                     0.0         yes       12427                  3
# 3                     0.0         yes       26088                  4
# 4                     0.0         yes       26405                  5
#
#    reordered                             product_name  department_id _merge
# ...

# %%
df_dept = pd.read_csv(os.path.join(path, '02. Data', 'Prepared Data', 'departments_wrangled.csv'), index_col = False)

# %%
df_dept.head()
# Out:
#    Unnamed: 0 department
# 0           1     frozen
# 1           2      other
# 2           3     bakery
# 3           4    produce
# 4           5    alcohol

# %%
df_dept.rename(columns = {'Unnamed: 0' : 'department_id'}, inplace = True)

# %%
df_dept.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
df_dept
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
df_ords['meat_eater'] = df_ords['department_id'].apply(lambda x: 'Yes' if x == 12 else 'No')

# %%
df_ords['department_id'] == '12'
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 32435054    False
# 32435055    False
# 32435056    False
# 32435057    False
# 32435058    False
# Name: department_id, Length: 32435059, dtype: bool

# %% [markdown]
# creating a subset of the df ie only 1000000 rows

# %%
df = df_ords[:1000000]

# %%
df_ords_checked = pd.read_csv(os.path.join(path, '02. Data', 'Prepared Data', 'order_checked.csv'))

# %%
df_ords_checked.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order first_order
# 0                   2                  8                     0.0         yes
# 1                   3                  7                    15.0          no
# 2                   3                 12                    21.0          no
# 3                   4                  7                    29.0          no
# 4                   4                 15                    28.0          no

# %%
df_prods_checked = pd.read_csv(os.path.join(path, '02. Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_merged_ords_prices = df_ords.merge(df_prods_checked[["product_id", "prices"]], on = 'product_id', how = "left", indicator = '_merge_prices')

# %%
df_merged_ords_prices.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order first_order  product_id  add_to_cart_order  \
# 0                     0.0         yes         196                  1
# 1                     0.0         yes       14084                  2
# 2                     0.0         yes       12427                  3
# 3                     0.0         yes       26088                  4
# 4                     0.0         yes       26405                  5
#
#    reordered                             product_name  department_id _merge  \
# ...

# %%
df = df_merged_ords_prices[:1000000]

# %% [markdown]
# Creating a user-defined function for price

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_15860\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.value_counts('price_range')
# Out:
# price_range
# Mid-range product    672523
# Low-range product    314111
# High range            12413
# Not enough data         953
# Name: count, dtype: int64

# %% [markdown]
# Checking the highest value

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
print(df[df['prices'] >= 100])
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 1576      912404       17            12                   2
# 1638      603376       17            22                   6
# 16534    3264360      135             2                   2
# 16540     892534      135             3                   0
# 53714     229704      342             8                   1
# ...          ...      ...           ...                 ...
# 959909    840159     6217            13                   1
# 959955   1235750     6217            20                   5
# 961209     40712     6221             5                   0
# 961283   2567369     6221            10                   2
# 961444    842052     6222            10                   1
#
#         order_hour_of_day  days_since_prior_order first_order  product_id  \
# 1576                   14                     5.0          no       21553
# 1638                   16                     4.0          no       21553
# ...

# %% [markdown]
# At this stage i have noticed that there appears to be one product with a price of 14900, which must be wrong... i assume that it should be 1.49. Perhaps i will need to correct this later. There is also a product with a price of 99999 which must also be wrong, but it might be that the price is missing and therefore this value has been imputed. this might require further investigation.

# %% [markdown]
# Deriving a new variable using loc()

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_15860\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df.head
# Out:
# <bound method NDFrame.head of         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2539329        1             1                   2
# 2        2539329        1             1                   2
# 3        2539329        1             1                   2
# 4        2539329        1             1                   2
# ...          ...      ...           ...                 ...
# 999995   1876509     6467            51                   2
# 999996   1876509     6467            51                   2
# 999997   1876509     6467            51                   2
# 999998   1876509     6467            51                   2
# 999999   1876509     6467            51                   2
#
#         order_hour_of_day  days_since_prior_order first_order  product_id  \
# 0                       8                     0.0         yes         196
# ...

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     672523
# Low-range product     314111
# High-range product     12413
# NaN                      953
# Name: count, dtype: int64

# %% [markdown]
# performing the loc() function on the whole df

# %%
df_merged_ords_prices.loc[df_merged_ords_prices['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_merged_ords_prices.loc[(df_merged_ords_prices['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_merged_ords_prices.loc[df_merged_ords_prices['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_merged_ords_prices['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# NaN                   21219115
# Low-range product     10126883
# Mid-range product       672523
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# printing the frequency of a column

# %%
df_merged_ords_prices['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6210092
# 1    5666141
# 6    4500565
# 2    4218008
# 5    4209743
# 3    3844291
# 4    3787359
# Name: count, dtype: int64

# %% [markdown]
# creating an empty list

# %%
result = []
for value in df_merged_ords_prices["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# combining this list with the df by creating a new variable

# %%
df_merged_ords_prices['busiest_day'] = result

# %%
df_merged_ords_prices['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22438748
# Busiest day        6210092
# Least busy         3787359
# Name: count, dtype: int64

# %% [markdown]
# Creating a new empty list for days

# %%
result2 = []
for value in df_merged_ords_prices["orders_day_of_week"]:
  if value in [0, 1]:
    result2.append("Busiest days")
  elif value in [3, 4]:
    result2.append("Slowest days")
  else:
    result2.append("Regularly busy")

# %%
result2
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
# ...

# %% [markdown]
# Merging the list to the df

# %%
df_merged_ords_prices['busiest_days'] = result2

# %% [markdown]
# Printing the frequency for the new column

# %%
df_merged_ords_prices['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12928316
# Busiest days      11876233
# Slowest days       7631650
# Name: count, dtype: int64

# %% [markdown]
# deleting the unnecessary column busiest_day

# %%
df_merged_ords_prices.drop(columns=['busiest_day'], inplace=True)

# %% [markdown]
# Identifying the hours with the most orders

# %%
df_merged_ords_prices['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2764576
# 11    2738777
# 14    2691698
# 15    2664683
# 13    2663454
# 12    2621000
# 16    2537602
# 9     2456827
# 17    2089600
# 8     1720027
# 18    1638022
# 19    1259446
# 20     977071
# 7      891979
# 21     796397
# 22     634761
# 23     402623
# 6      290798
# 0      218957
# 1      115789
# 5       88068
# 2       69437
# 4       53286
# 3       51321
# Name: count, dtype: int64

# %% [markdown]
# creating an empty list

# %%
result3 = []
for value in df_merged_ords_prices["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    result3.append("Most orders")
  elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
    result3.append("Average order")
  else:
    result3.append("Fewest orders")

# %%
result3
# Out:
# ['Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Average order',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average order',
#  'Average order',
#  'Average order',
# ...

# %% [markdown]
# Merging the list to the df

# %%
df_merged_ords_prices['busiest_period_of_day'] = result3

# %% [markdown]
# Printing the frequency for the new column

# %%
df_merged_ords_prices['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders      21138617
# Average order    10007303
# Fewest orders     1290279
# Name: count, dtype: int64

# %%
df_merged_ords_prices.to_pickle(os.path.join(path, '02. Data','Prepared Data', 'order_products_new_variables.pkl'))
